# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import datasets

data = datasets.load_iris()
#create a DataFrame
df = pd.DataFrame(data.data, columns=data.feature_names)
df['Target'] = pd.DataFrame(data.target)
print(df.shape)
df.head()
# Out:
# (150, 5)
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    Target
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0

# %%
import matplotlib.pyplot as plt
from convex_hull_by_hana import myConvexHull, titik_menjadi_indeks
plt.figure(figsize = (10, 6))
colors = ['b','r','g']
plt.title('Petal Width vs Petal Length')
plt.xlabel(data.feature_names[0])
plt.ylabel(data.feature_names[1])
for i in range(len(data.target_names)):
    bucket = df[df['Target'] == i]
    bucket = bucket.iloc[:,[0,1]].values
    result = myConvexHull(bucket)
    #print(result[0])
    #print(result[1])
    #print(result[2])
    #print(titik_menjadi_indeks(result_npy[0][0], result_npy[0][1], bucket))
    plt.scatter(bucket[:, 0], bucket[:, 1], label=data.target_names[i])
    for simplex in result[0]:
        plt.plot(bucket[simplex, 0], bucket[simplex, 1], colors[i])
        plt.plot(bucket [result_npy[0][0],result_npy[1][0]], [result_npy[0][1],result_npy[1][1]] , colors[1])
plt.legend()
# Out:
# [[4.3 3. ]
#  [5.8 4. ]
#  [5.7 4.4]
#  [5.7 3.8]]
# [[4.4 3.2]
#  [4.6 3.4]
#  [4.6 3.6]
#  [4.8 3.4]
#  [4.8 3.4]
#  [4.9 3.6]
#  [5.  3.6]
#  [5.  3.5]
#  [5.  3.5]
#  [5.1 3.8]
#  [5.1 3.7]
#  [5.1 3.8]
#  [5.1 3.8]
#  [5.2 4.1]
#  [5.3 3.7]
#  [5.4 3.9]
#  [5.4 3.9]
#  [5.5 4.2]
#  [5.7 4.4]]
# [[4.4 2.9]
#  [4.4 3. ]
#  [4.5 2.3]
#  [4.6 3.1]
#  [4.7 3.2]
#  [4.7 3.2]
#  [4.8 3. ]
#  [4.8 3.1]
#  [4.8 3. ]
#  [4.9 3. ]
#  [4.9 3.1]
#  [4.9 3.1]
#  [5.  3.4]
#  [5.  3. ]
#  [5.  3.4]
#  [5.  3.2]
#  [5.  3.3]
#  [5.1 3.5]
#  [5.1 3.5]
#  [5.1 3.3]
#  [5.1 3.4]
#  [5.2 3.5]
#  [5.2 3.4]
#  [5.4 3.7]
#  [5.4 3.4]
#  [5.4 3.4]
#  [5.5 3.5]
#  [5.7 3.8]]
# [[4.9 2.4]
#  [7.  3.2]
#  [6.3 3.3]
#  [6.9 3.1]]
# [[5.1 2.5]
#  [5.2 2.7]
#  [5.4 3. ]
#  [5.6 2.9]
#  [5.6 3. ]
#  [5.6 3. ]
#  [5.6 2.7]
#  [5.7 2.8]
#  [5.7 3. ]
#  [5.7 2.9]
#  [5.7 2.8]
#  [5.9 3. ]
#  [5.9 3.2]
#  [6.  2.9]
#  [6.  3.4]
#  [6.1 2.9]
#  [6.1 3. ]
#  [6.2 2.9]
#  [6.3 3.3]
#  [6.4 3.2]
#  [6.7 3.1]
# ...
